# %%
from stockx_api import stockx_api_search

# %%
response = stockx_api_search('air-jordan-4-retro-military-blue-2024', '10')
print(response)
# Out:
# <p>{'Pagination': {'query': 'air-jordan-4-retro-military-blue-2024?size=10', 'queryID': '235f4fe9ecb7ba0e1ab76ea8330baf8e', 'index': 'PRODUCTION_PG_FEATURED_DESC', 'limit': 40, 'page': 1, 'total': 114242, 'lastPage': '/api/v3/browse?_search=air-jordan-4-retro-military-blue-2024%3Fsize%3D10&amp;filterVersion=4&amp;page=25', 'sort': ['featured'], 'order': ['DESC'], 'currentPage': '/api/v3/browse?_search=air-jordan-4-retro-military-blue-2024%3Fsize%3D10&amp;filterVersion=4', 'nextPage': '/api/v3/browse?_search=air-jordan-4-retro-military-blue-2024%3Fsize%3D10&amp;filterVersion=4&amp;page=2', 'previousPage': None}, 'Facets': {'uuid': {'000c1868-1002-4ff7-a731-424bca1d6304': 41, '002e9251-de12-4a99-894e-38ac74832e98': 41, '002f662b-9f40-4c3f-8c9f-e1e834427d73': 41, '00467a42-ab94-40be-b439-14042c459244': 41, '005a32ff-2792-46ad-9620-f61bd00dca4a': 41, '0092a801-d498-4407-9f0e-ea230c46b2f0': 41, '00c8baba-7a8f-43c7-b423-aec0946545f8': 41, '00e7156c-53f9-41a4-917a-07c4d053f5dc': 41, '0104db
# ...
